# %%
from llm_preproc import LLM_preprocessing

# %% [markdown]
# !Внимание! Этот скрипт работает только с локальным сервером, на котором развернута большая языковая модель. Структура обращения к серверу описана в файле класса:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
LLM_preprocessing("output.xlsx")
